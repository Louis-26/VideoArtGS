# %%
import os
from moviepy.editor import VideoFileClip
import numpy as np
import cv2
from glob import glob


def video2gif_ffmpeg(video_file):
    gif_file = video_file.replace('.mkv', '.gif').replace('.mp4', '.gif')
    os.makedirs(os.path.dirname(gif_file), exist_ok=True)
    cmd = f'ffmpeg -i {video_file} -vf "fps=10,scale=480:-1:flags=lanczos,split[s0][s1];[s0]palettegen[p];[s1][p]paletteuse" {gif_file} -y'
    os.system(cmd)


def video2gif(video_file):
    gif_file = video_file.replace('.mp4', '.gif')
    clip = VideoFileClip(video_file)
    clip.write_gif(gif_file)
    clip.close()

def generate_video_ffmpeg(img_path, video_name, fps=30):
    if os.path.exists(video_name):
        os.system(f'rm {video_name}')
    os.system(f'ffmpeg -framerate {fps} -vsync 0 -i {img_path}' + '/%06d.png -c:v libx264 -crf 0 ' + video_name)

def generate_video(img_path, video_name, fps=15, brighten=False, white_background=False):
    # imgs: list of img tensors [3, H, W]
    imgs = sorted(glob(f'{img_path}/*.png'))
    # imgs = imgs[100:]
    imgs = [cv2.imread(img, -1) for img in imgs] # rgba
    # transfer to rgb with white background
    print(f'Generating video {video_name} with {len(imgs)} frames')
    for i, img in enumerate(imgs):
        if img is None:
            print(f'img {i} is None')
            continue
        if img.shape[-1] == 4:
            imgs[i] = img[:, :, :3] * (img[:, :, 3:4] / 255.0) 
            if white_background:
                imgs[i] = imgs[i] + 255 * (1 - img[:, :, 3:4] / 255.0)
            imgs[i] = imgs[i].astype(np.uint8)
    height, width = imgs[0].shape[0], imgs[0].shape[1]
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video = cv2.VideoWriter(video_name, fourcc, fps, (width, height))

    for img in imgs:
        if brighten:
            img = cv2.convertScaleAbs(img, alpha=1.5, beta=1)
        video.write(img)
    video.release()

# %%
dataset = 'videoartgs'
subset = 'sapien'
# subset = 'realscan'

scene = '30666'
# scene = '10655_new'
file_dir = f"../outputs/{dataset}/{subset}/{scene}/final/train/ours_20000"
img_path = f"{file_dir}/renders/-1"
# img_path = f"{file_dir}/track_frames"
# img_path = '/mnt/fillipo/yuliu/wallbreaker/Projects/VideoArtGS/outputs/artgs/realscan/microwave1/demo1/render_cam/ours_20000/rgba'
# file_dir = f"../data/{dataset}/{subset}/{scene}"
# video_file = f'{file_dir}/{scene}_mask.mp4'
video_file = f'{file_dir}/{scene}_axis.mp4'
# generate_video(img_path, video_file, 20)
    # generate_video_ffmpeg(img_path, video_file, 30)
    # video2gif(video_file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 14
#       9 # img_path = f"{file_dir}/track_frames"
#      10 # img_path = '/mnt/fillipo/yuliu/wallbreaker/Projects/VideoArtGS/outputs/artgs/realscan/microwave1/demo1/render_cam/ours_20000/rgba'
#      11 # file_dir = f"../data/{dataset}/{subset}/{scene}"
#      12 # video_file = f'{file_dir}/{scene}_mask.mp4'
#      13 video_file = f'{file_dir}/{scene}_axis.mp4'
# ---> 14 generate_video(img_path, video_file, 20)
#      15     # generate_video_ffmpeg(img_path, video_file, 30)
#      16     # video2gif(video_file)
#
# Cell In[7], line 30, in generate_video(img_path, video_name, fps, brighten, white_background)
#      28 imgs = sorted(glob(f'{img_path}/*.png'))
#      29 # imgs = imgs[100:]
# ---> 30 imgs = [cv2.imread(img, -1) for img in imgs] # rgba
#      31 # transfer to rgb with white background
#      32 print(f'Generating video {video_name} with {len(imgs)} frames')
#
# Cell In[7], line 30, in <listcomp>(.0)
#      28 imgs = sorted(glob(f'{img_path}/*.png'))
#      29 # imgs = imgs[100:]
# ---> 30 imgs = [cv2.imread(img, -1) for img in imgs] # rgba
#      31 # transfer to rgb with white background
#      32 print(f'Generating video {video_name} with {len(imgs)} frames')
#
# KeyboardInterrupt:

# %%
dataset = 'videoartgs'
subset = 'sapien'
# subset = 'realscan'
# scene = 'mac_1r'
scene = '30666'
# file_dir = f"../outputs/{dataset}/{subset}/{scene}/artgs/train/ours_best"
# file_dir = f"../data/{dataset}/{subset}/{scene}"
# img_path = f"{file_dir}/images"

# file_dir = f"/mnt/fillipo/yuliu/HumanVLA/scenes/real1/"
# img_path = f"{file_dir}/masks_vis"
# print(img_path)
video_file = f'{file_dir}/{scene}_video.mp4'
os.system(f'rm {video_file}')
if not os.path.exists(video_file):
    # generate_video(img_path, video_file, 10)
    generate_video_ffmpeg(img_path, video_file, 20)
    # video2gif(video_file)
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.3.0 (conda-forge gcc 14.3.0-16)
#   configuration: --prefix=/data/svillar3/ylu174/Anaconda3/envs/videoartgs --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-alsa --enable-libpulse --enable-libvpl --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-libjxl --enable-libwebp --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# -vsync is deprecated. Use -fps_mode
# Passing a number to -vsync is deprecated, use a string argument as described in the manual.
# Input #0, image2, from '../outputs/videoartgs/sapien/30666/final/train/ours_20000/renders/-1/%06d.png':
#   Duration: 00:00:30.00, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown), 800x800, 20 fps, 20 tbr, 20 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5555555ff000] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5555555ff000] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5555555ff000] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=25 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=20 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to '../outputs/videoartgs/sapien/30666/final/train/ours_20000/masks_vis.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv444p(tv, progressive), 800x800, q=2-31, 20 fps, 10240 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x5555555fcbc0] video:40015KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.009269%
# frame=  600 fps=9.8 q=-1.0 Lsize=   40019KiB time=00:00:30.00 bitrate=10927.9kbits/s speed=0.491x elapsed=0:01:01.09
# [libx264 @ 0x5555555ff000] frame I:4     Avg QP: 0.00  size: 67602
# [libx264 @ 0x5555555ff000] frame P:596   Avg QP: 0.00  size: 68297
# [libx264 @ 0x5555555ff000] mb I  I16..4: 15.4% 78.8%  5.8%
# [libx264 @ 0x5555555ff000] mb P  I16..4:  5.7%  1.8%  3.9%  P16..4:  3.2%  3.6%  4.0%  0.0%  0.0%    skip:77.9%
# [libx264 @ 0x5555555ff000] 8x8 transform intra:19.3% inter:30.3%
# [libx264 @ 0x5555555ff000] coded y,u,v intra: 80.5% 77.7% 76.7% inter: 11.3% 11.0% 10.9%
# [libx264 @ 0x5555555ff000] i16 v,h,dc,p: 47% 53%  0%  0%
# [libx264 @ 0x5555555ff000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 47% 23%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x5555555ff000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 44%  5%  3%  5%  3%  4%  2%  2%
# [libx264 @ 0x5555555ff000] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5555555ff000] ref P L0: 77.3%  6.9%  9.7%  6.1%
# [libx264 @ 0x5555555ff000] kb/s:10926.72
# MoviePy - Building file ../outputs/videoartgs/sapien/30666/final/train/ours_20000/masks_vis.gif with imageio.

# %%
# video_file = '/home/yuliu/seq02.mp4'
# video2gif_ffmpeg(video_file)
# video_file = '/mnt/fillipo/yuliu/VideoArtGS/videos/cab2.mp4'
video_file="/scratch4/enalisn1/ylu174/VideoArtGS/outputs/videoartgs/sapien/30666/final/train/ours_20000/30666_video.mp4"
video2gif_ffmpeg(video_file)
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.3.0 (conda-forge gcc 14.3.0-16)
#   configuration: --prefix=/data/svillar3/ylu174/Anaconda3/envs/videoartgs --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-alsa --enable-libpulse --enable-libvpl --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-libjxl --enable-libwebp --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/scratch4/enalisn1/ylu174/VideoArtGS/outputs/videoartgs/sapien/30666/final/train/ours_20000/30666_video.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf62.3.100
#   Duration: 00:00:30.00, start: 0.000000, bitrate: 10927 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv444p(progressive), 800x800, 10926 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> gif (native))
# Press [q] to stop, [?] for help
# [Parsed_palettegen_3 @ 0x155538012140] 255(+1) colors generated out of 195811 colors; ratio=0.001302
# Output #0, gif, to '/scratch4/enalisn1/ylu174/VideoArtGS/outputs/videoartgs/sapien/30666/final/train/ours_20000/30666_video.gif':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: gif, pal8(pc, gbr/unknown/unknown, progressive), 480x480, q=2-31, 200 kb/s, 10 fps, 100 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 gif
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# [out#0/gif @ 0x555555608280] video:9996KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000195%
# frame=  300 fps= 13 q=-0.0 Lsize=    9996KiB time=00:00:30.00 bitrate=2729.6kbits/s speed=1.29x elapsed=0:00:23.19
