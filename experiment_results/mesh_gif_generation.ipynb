# %%
from gif_video_generate import *
from visualize_mesh import *
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# # get video and gif
# generate_video_gif('videoartgs', 'sapien', '47648')
# # get mesh segmentation results
# color_parts('47648', dataset="videoartgs", base="..")

# %%
import glob, os

base = ".."  
subset="realscan"
def list_renderable(dataset, subset):
    pattern = f"{base}/outputs/{dataset}/{subset}/*/final/train/ours_20000/meshes/part_0.ply"
    scenes = []
    for p in sorted(glob.glob(pattern)):
        scene = p.split(f"/{subset}/")[1].split("/")[0]
        scenes.append(scene)
    return scenes

VideoArtGS_scenes = list_renderable("videoartgs", "realscan")
# V2a_scenes = list_renderable("v2a", "sapien")

print("VideoArtGS scene number with realscan:", len(VideoArtGS_scenes))
print(VideoArtGS_scenes)
# print("V2a scene number:", len(V2a_scenes))
# print(V2a_scenes)
# Out:
# VideoArtGS scene number with realscan: 7
# ['cab1', 'cab_1r_1p', 'chair_1r', 'coffeemachine_2r', 'mac_1r', 'microwave_1r', 'microwave_ego']

# %%
VideoArtGS_scenes=["168"]
subset="sapien"
for scene in VideoArtGS_scenes:
    generate_video_gif('videoartgs', subset, scene)
    color_parts(scene, dataset="videoartgs", subset=subset, base="..")

# for scene in V2a_scenes:
#     generate_video_gif('v2a', 'sapien', scene)
#     color_parts(scene, dataset="v2a", base="..")
# Out:
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.3.0 (conda-forge gcc 14.3.0-16)
#   configuration: --prefix=/data/svillar3/ylu174/Anaconda3/envs/videoartgs --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-alsa --enable-libpulse --enable-libvpl --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-libjxl --enable-libwebp --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# -vsync is deprecated. Use -fps_mode
# Passing a number to -vsync is deprecated, use a string argument as described in the manual.
# Input #0, image2, from '../outputs/videoartgs/sapien/168/final/train/ours_20000/renders/-1/%06d.png':
#   Duration: 00:00:12.50, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc, gbr/unknown/unknown), 800x800, 20 fps, 20 tbr, 20 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5555555ff340] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5555555ff340] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5555555ff340] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=0 mixed_ref=1 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=0 chroma_qp_offset=0 threads=25 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=2 keyint=250 keyint_min=20 scenecut=40 intra_refresh=0 rc=cqp mbtree=0 qp=0
# Output #0, mp4, to '../outputs/videoartgs/sapien/168/final/train/ours_20000/168_video.mp4':
#   Metadata:
#     encoder         : Lavf62.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv444p(tv, progressive), 800x800, q=2-31, 20 fps, 10240 tbn
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x5555555fc7c0] video:3925KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.047023%
# frame=  250 fps= 15 q=-1.0 Lsize=    3927KiB time=00:00:12.50 bitrate=2573.6kbits/s speed=0.758x elapsed=0:00:16.49
# [libx264 @ 0x5555555ff340] frame I:1     Avg QP: 0.00  size: 13688
# [libx264 @ 0x5555555ff340] frame P:249   Avg QP: 0.00  size: 16085
# [libx264 @ 0x5555555ff340] mb I  I16..4:  3.3% 94.3%  2.4%
# [libx264 @ 0x5555555ff340] mb P  I16..4:  3.6%  0.2%  2.2%  P16..4:  1.4%  0.8%  0.6%  0.0%  0.0%    skip:91.2%
# [libx264 @ 0x5555555ff340] 8x8 transform intra:9.1% inter:6.7%
# [libx264 @ 0x5555555ff340] coded y,u,v intra: 62.7% 51.7% 44.8% inter: 2.4% 2.0% 1.7%
# [libx264 @ 0x5555555ff340] i16 v,h,dc,p: 94%  6%  0%  0%
# [libx264 @ 0x5555555ff340] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42%  8% 48%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x5555555ff340] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 44% 28%  8%  3%  6%  4%  4%  3%  1%
# [libx264 @ 0x5555555ff340] Weighted P-Frames: Y:0.4% UV:0.0%
# [libx264 @ 0x5555555ff340] ref P L0: 84.4%  5.4%  7.5%  2.6%
# [libx264 @ 0x5555555ff340] kb/s:2572.02
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.3.0 (conda-forge gcc 14.3.0-16)
#   configuration: --prefix=/data/svillar3/ylu174/Anaconda3/envs/videoartgs --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-alsa --enable-libpulse --enable-libvpl --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-libjxl --enable-libwebp --enable-ffplay --enable-vulkan --enable-libshaderc --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1769712549653/_build_env/bin/pkg-config
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../outputs/videoartgs/sapien/168/final/train/ours_20000/168_video.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf62.3.100
#   Duration: 00:00:12.50, start: 0.000000, bitrate: 2573 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High 4:4:4 Predictive) (avc1 / 0x31637661), yuv444p(progressive), 800x800, 2572 kb/s, 20 fps, 20 tbr, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> gif (native))
# Press [q] to stop, [?] for help
# [Parsed_palettegen_3 @ 0x155538012140] 255(+1) colors generated out of 19807 colors; ratio=0.012874
# [Parsed_palettegen_3 @ 0x155538012140] Duped color: FF9A9AAA
# [Parsed_palettegen_3 @ 0x155538012140] Duped color: FFA1A1B1
# [Parsed_palettegen_3 @ 0x155538012140] Duped color: FFB4B4C4
# Output #0, gif, to '../outputs/videoartgs/sapien/168/final/train/ours_20000/168_video.gif':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: gif, pal8(pc, gbr/unknown/unknown, progressive), 480x480, q=2-31, 200 kb/s, 10 fps, 100 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 gif
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# [out#0/gif @ 0x555555624280] video:1562KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.001250%
# frame=  125 fps= 20 q=-0.0 Lsize=    1562KiB time=00:00:12.50 bitrate=1023.9kbits/s speed=2.02x elapsed=0:00:06.20
# 168: 3 parts -> ../outputs/videoartgs/sapien/168/final/train/ours_20000/168_colored.ply
